# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishgowda1581999-glitch/nitishgowdag/blob/main/Level_1_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = "/content/Dataset  (1).csv"
df = pd.read_csv(file_path)

# Display the first 5 rows of the DataFrame
display(df.head())

# Display the column names and their data types
display(df.info())
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # Task
# Analyze the distribution of ratings for the top 3 cuisines in the dataset "/content/Dataset (1).csv".

# %% [markdown]
# ## Identify top cuisines
#
# ### Subtask:
# Extract the names of the top 3 cuisines from the `cuisine_counts` Series.

# %% [markdown]
# **Reasoning**:
# Extract the names of the top 3 cuisines from the `cuisine_counts` Series.

# %%
# Get the value counts for the 'Cuisines' column
cuisine_counts = df['Cuisines'].value_counts()

# Display the top 3 most common cuisines
display("Top 3 Most Common Cuisines:")
display(cuisine_counts.head(3))
# Out:
# 'Top 3 Most Common Cuisines:'
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %% [markdown]
# ## Filter data
#
# ### Subtask:
# Filter the original DataFrame to include only restaurants that offer one of the top 3 cuisines.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame to include only the top 3 cuisines identified in the previous step.

# %%
df_top_cuisines = df[df['Cuisines'].isin(top_3_cuisines)]
display(df_top_cuisines.head())
# Out:
#      Restaurant ID               Restaurant Name  Country Code  \
# 5         18189371                  Din Tai Fung           162
# 93        17284150  House of China Restaurant II           216
# 172       17316208            Ting's Red Lantern           216
# 199       17330087  Chef Lee's Peking Restaurant           216
# 241       17334718                    China Cafe           216
#
#                        City  \
# 5          Mandaluyong City
# 93                   Albany
# 172  Cedar Rapids/Iowa City
# 199                Columbus
# 241               Davenport
#
#                                                Address  \
# 5    Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 93              2526 Dawson Rd Ste A, Albany, GA 31707
# 172           540 Boyson Rd NE, Cedar Rapids, IA 52402
# 199           6100 Bradley Park Dr, Columbus, GA 31904
# 241                3018 E 53rd St, Davenport, IA 52807
#
#                                    Locality  \
# ...

# %% [markdown]
# ## Visualize rating distribution
#
# ### Subtask:
# Create a visualization (e.g., a histogram or box plot) to show the distribution of 'Aggregate rating' for the filtered data.

# %% [markdown]
# **Reasoning**:
# Create a box plot to visualize the distribution of aggregate ratings for the top 3 cuisines.

# %%
# Display summary statistics for the filtered DataFrame
display("Summary Statistics for Top 3 Cuisines Data:")
display(df_top_cuisines.describe())
# Out:
# 'Summary Statistics for Top 3 Cuisines Data:'
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   1.801000e+03   1801.000000  1801.000000  1801.000000
# mean    9.234936e+06      2.560800    71.780181    26.652981
# std     9.006214e+06     17.761719    22.100044     7.198204
# min     6.700000e+01      1.000000  -112.441000   -36.871779
# 25%     3.018170e+05      1.000000    77.100000    28.513031
# 50%     3.600119e+06      1.000000    77.203839    28.586413
# 75%     1.837791e+07      1.000000    77.293617    28.644156
# max     1.850065e+07    216.000000   174.752442    42.892800
#
#        Average Cost for two  Price range  Aggregate rating        Votes
# count           1801.000000  1801.000000       1801.000000  1801.000000
# mean             501.071627     1.506941          1.957635    61.176013
# std              500.518749     0.734152          1.579476   245.828505
# min               10.000000     1.000000          0.000000     0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Cuisines', y='Aggregate rating', data=df_top_cuisines)
plt.title("Distribution of Aggregate Ratings for Top 3 Cuisines")
plt.xlabel("Cuisines")
plt.ylabel("Aggregate Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The top 3 cuisines identified are 'North Indian', 'North Indian, Chinese', and 'Chinese'.
# *   A filtered DataFrame containing only restaurants offering these top 3 cuisines was created.
# *   A box plot was generated to visualize the distribution of aggregate ratings for each of the top 3 cuisines, showing the median, quartiles, and potential outliers for their ratings.
#
# ### Insights or Next Steps
#
# *   Analyze the median rating for each of the top 3 cuisines to understand which one generally receives higher ratings.
# *   Investigate the spread of ratings for each cuisine to assess the consistency of their reviews.
